# %%
import pandas as pd

# %%
go_df = pd.read_excel('../data/HUMAN_9606_idmapping.xlsx')

go_df
# Out:
#        UniProtKB-AC      UniProtKB-ID GeneID (EntrezGene)  \
# 0            P31946       1433B_HUMAN                7529
# 1            P62258       1433E_HUMAN                7531
# 2            Q04917       1433F_HUMAN                7533
# 3            P61981       1433G_HUMAN                7532
# 4            P31947       1433S_HUMAN                2810
# ...             ...               ...                 ...
# 207775       B4DID3      B4DID3_HUMAN                 NaN
# 207776       H9BQ89      H9BQ89_HUMAN                 NaN
# 207777       H9C5H6      H9C5H6_HUMAN                 NaN
# 207778       Q9HAQ5      Q9HAQ5_HUMAN                 NaN
# 207779   A0A186VNL2  A0A186VNL2_HUMAN                 NaN
#
#                                       Unnamed: 3  \
# 0       NP_003395.1; NP_647539.1; XP_016883528.1
# 1                                    NP_006752.1
# 2                                    NP_003396.1
# 3                                    NP_036611.2
# ...

# %%
go_df['GeneID (EntrezGene)']
# Out:
# 0         7529
# 1         7531
# 2         7533
# 3         7532
# 4         2810
#           ...
# 207775     NaN
# 207776     NaN
# 207777     NaN
# 207778     NaN
# 207779     NaN
# Name: GeneID (EntrezGene), Length: 207780, dtype: object

# %%
label_df = pd.read_csv('../data/cpg0016/version_2023-06-14/gene_labels.csv')
label_df
# Out:
#      Metadata_Symbol  Metadata_NCBI_Gene_ID  Indeterminate  Negative  \
# 0                A2M                      2              1         1
# 1            A3GALT2                 127550              1         0
# 2             A4GALT                  53947              0         0
# 3              A4GNT                  51146              3         0
# 4               AACS                  65985              1         0
# ...              ...                    ...            ...       ...
# 7970         ZSCAN32                  54925              4         0
# 7971          ZSCAN4                 201516              0         0
# 7972         ZSCAN5A                  79149              0         0
# 7973          ZSCAN9                   7746              0         0
# 7974          ZSWIM2                 151112              1         0
#
#       Positive     gene_label
# 0            3       Positive
# 1            4       Positive
# 2            5       Positive
# ...

# %%
go_df[go_df['GeneID (EntrezGene)'] == 53947]
# Out:
#       UniProtKB-AC      UniProtKB-ID GeneID (EntrezGene)  \
# 88          Q9NPC4       A4GAT_HUMAN               53947
# 57684   A0A0S2Z5J1  A0A0S2Z5J1_HUMAN               53947
#
#                                               Unnamed: 3  \
# 88     NP_001304967.1; NP_059132.1; XP_005261701.1; X...
# 57684  NP_001304967.1; NP_059132.1; XP_005261701.1; X...
#
#                                               Unnamed: 4 Unnamed: 5  \
# 88     530420175; 25452796; 1034629093; 530420171; 76...        NaN
# 57684  60459546; 15523687; 189066521; 957951157; 5304...        NaN
#
#                                               Unnamed: 6        Unnamed: 7  \
# 88     GO:0000139; GO:0016020; GO:0008375; GO:0008378...  UniRef100_Q9NPC4
# 57684     GO:0000139; GO:0050512; GO:0015643; GO:0001576  UniRef100_Q9NPC4
#
#             Unnamed: 8       Unnamed: 9  ... Unnamed: 12     Unnamed: 13  \
# 88     UniRef90_Q9NPC4  UniRef50_Q9NPC4  ...      9606.0  111400; 607922
# ...

# %%
go_subset = go_df[go_df['GeneID (EntrezGene)'].isin(label_df['Metadata_NCBI_Gene_ID'])]

# %%
go_terms = go_subset['Unnamed: 6'].str.split('; ')
go_terms
# Out:
# 1         [GO:0005737, GO:0005829, GO:0070062, GO:000592...
# 3         [GO:0005737, GO:0005829, GO:0070062, GO:000592...
# 5         [GO:0005737, GO:0005829, GO:0070062, GO:000592...
# 9         [GO:0005813, GO:0000775, GO:0005737, GO:000582...
# 10        [GO:0005737, GO:0005829, GO:0005634, GO:000015...
#                                 ...
# 207620    [GO:0031012, GO:0016020, GO:0004222, GO:000827...
# 207677                             [GO:0000139, GO:0006891]
# 207709    [GO:0005829, GO:0045171, GO:0072686, GO:000565...
# 207730                             [GO:0046872, GO:0006355]
# 207748                                         [GO:0005634]
# Name: Unnamed: 6, Length: 14773, dtype: object

# %%
gomap = pd.DataFrame({'Gene': go_subset['GeneID (EntrezGene)'], 'GO': go_terms}).explode('GO')
gomap
# Out:
#         Gene          GO
# 1       7531  GO:0005737
# 1       7531  GO:0005829
# 1       7531  GO:0070062
# 1       7531  GO:0005925
# 1       7531  GO:0042470
# ...      ...         ...
# 207709  3174  GO:0043565
# 207709  3174  GO:0008270
# 207730  7551  GO:0046872
# 207730  7551  GO:0006355
# 207748  9439  GO:0005634
#
# [193564 rows x 2 columns]

# %%
gomat = gomap.pivot_table(index='Gene', columns='GO', aggfunc=lambda _:1, fill_value=0)

# %%
gomat.loc[7531,'GO:0005829']
# Out:
# 1
